# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/Third_good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 271 # no of stations
lat = np.array(geo_df.iloc[:267,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:267,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:271,2])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)

plt.clim(-1,1)
plt.title('Jan Feb Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/Third_good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 271 # no of stations
lat = np.array(geo_df.iloc[:267,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:267,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:271,3])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)

plt.clim(-1,1)
plt.title('Feb Mar Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/Third_good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 271 # no of stations
lat = np.array(geo_df.iloc[:267,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:267,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:271,4])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)

plt.clim(-1,1)
plt.title('Mar Apr Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/Third_good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 271 # no of stations
lat = np.array(geo_df.iloc[:267,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:267,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:271,5])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)

plt.clim(-1,1)
plt.title('Apr May Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/Third_good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 271 # no of stations
lat = np.array(geo_df.iloc[:267,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:267,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:271,6])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)

plt.clim(-1,1)
plt.title('May June Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/Third_good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 271 # no of stations
lat = np.array(geo_df.iloc[:267,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:267,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:271,7])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)

plt.clim(-1,1)
plt.title('June July Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/Third_good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 271 # no of stations
lat = np.array(geo_df.iloc[:267,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:267,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:271,8])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)

plt.clim(-1,1)
plt.title('July Aug Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 330 # no of stations
lat = np.array(geo_df.iloc[:326,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:326,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:330,9])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)
plt.clim(-1,1)

plt.title('Aug Sept Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/Third_good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 271 # no of stations
lat = np.array(geo_df.iloc[:267,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:267,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:271,10])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)

plt.clim(-1,1)
plt.title('Sept Oct Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/Third_good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 271 # no of stations
lat = np.array(geo_df.iloc[:267,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:267,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:271,11])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)

plt.clim(-1,1)
plt.title('Oct Nov Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 330 # no of stations
lat = np.array(geo_df.iloc[:326,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:326,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:330,12])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)
plt.clim(-1,1)

plt.title('Nov Dec Correlation')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
geo_df=pd.read_csv('ghcnm_out/Correlated Data/Third_good_final_data.csv')

#Define mapframe
lllon = -180
lllat = 60
urlon = 180
urlat = 90

# Make some toy data, random points + corners
n = 271 # no of stations
lat = np.array(geo_df.iloc[:267,14])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:267,15])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:271,13])
# set up basemap chose projection!
m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)

# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(12, 12))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)

plt.colorbar(shrink=0.65)

plt.clim(-1,1)
plt.title('Dec Jan Correlation')

plt.show()
