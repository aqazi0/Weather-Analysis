# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,6])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('Jan Feb Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,7])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('Feb Mar Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,8])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('Mar Apr Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,9])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('Apr May Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,10])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('May June Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,11])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('June July Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,12])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('July Aug Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,13])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('Aug Sept Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,14])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('Sept Oct Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,15])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('Oct Nov Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,16])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('Nov Dec Correlation')

plt.show()

# %%
# %matplotlib inline
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from itertools import chain
import pandas as pd
geo_df=pd.read_csv('Iceland.csv')


lllon = 14
lllat = 63
urlon = 25
urlat = 67


n = 18 # no of stations
lat = np.array(geo_df.iloc[:14,2])
lat = np.append(lat, [lllat, urlat, urlat, lllat]) 
lon = np.array(geo_df.iloc[:14,3])
lon = np.append(lon, [lllon, urlon, lllon, urlon])
data = np.array(geo_df.iloc[:18,17])


m = Basemap(projection='gnom', lat_0=65, lon_0=-17.5,
                width=800000, height=800000, resolution='h')

# transform coordinates to map projection m
m_lon, m_lat = m(*(lon, lat))

# generate grid data
numcols, numrows = 240, 240
xi = np.linspace(m_lon.min(), m_lon.max(), numcols)
yi = np.linspace(m_lat.min(), m_lat.max(), numrows)
xi, yi = np.meshgrid(xi, yi)


# interpolate, there are better methods, especially if you have many datapoints
zi = griddata((m_lon,m_lat),data,(xi,yi),method='linear')

fig, ax = plt.subplots(figsize=(20, 20))

# draw map details
m.shadedrelief()
# m.drawmapboundary(fill_color = 'lightgreen', zorder = 1)

# Plot interpolated temperatures
m.contourf(xi, yi, zi, 500, cmap='RdBu', zorder = 2)

m.drawlsmask(ocean_color='skyblue', land_color=(0, 0, 0, 0), lakes=True, zorder = 3)

m.drawparallels(np.arange(-80.,81.,10.),  linewidth=0.4)
m.drawmeridians(np.arange(-180.,181.,10.),  linewidth=0.4)
m.drawcoastlines()
plt.colorbar(shrink=0.65)
plt.clim(-1, 1) 
plt.title('Dec Jan Correlation')

plt.show()
